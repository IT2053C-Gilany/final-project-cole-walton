# %% [markdown]
# # Project Title - Edit Me

# %% [markdown]
# ## Data set selection
#
# > In this section, you will need to provide the following information about the selected data set:
# >
# > - Source with a link
# > - Fields
# > - License
#
# ### Data set selection rationale
#
# > Why did you select this data set?
#
# ### Questions to be answered
#
# > Using statistical analysis and visualization, what questions would you like to be able answer about this dataset.
# > This could include questions such as:
# >
# > - What is the relationship between X and Y variables?
# > - What is the distribution of the variables?
# > - What is the relationship between the variables and the target?
# >   You will need to frame these questions in a way to show value to a stakeholder (i.e.why should we know about the relationship between X and Y variables?)
#
# ### Visualization ideas
#
# > Provide a few examples of what you plan to visualize to answer the questions you posed in the previous section. In this project, you will be producing 6-8 visualizations. You will also be producing an interactive chart using Plotly.
# > Think about what those visualization could be: what are the variables used in the charts? what insights do you hope to gain from them?

# %% [markdown]
# source: https://github.com/jldbc/pybaseball
#
# Fields: The dataset contains MLB player-level and pitch-level data fields such as:
#
# player_name – Player’s name
#
# year – Season year
#
# team – MLB team abbreviation
#
# handedness – Left- or right-handed batter/pitcher
#
# exit_velocity_avg – Average exit velocity of batted balls
#
# launch_angle_avg – Average launch angle
#
# whiff_rate – Percentage of swings that result in a miss
#
# chase_rate – Percentage of swings at pitches outside the strike zone
#
# barrel_rate – Rate of well-hit balls (“barrels”) per batted ball event
#
# woba – Weighted On-Base Average (overall hitting performance)
#
# era / k_rate / bb_rate (for pitchers) – Core pitching performance metrics
#
# License: MIT License, free to use and modify for academic and personal projects.
#
# Data Set Selection Rationale: I chose the pybaseball dataset because it provides real MLB Statcast data, the same kind that professional teams use for player evaluation. As someone interested in baseball analytics and scouting, this dataset directly connects to my career goals. It allows me to analyze player performance trends, find data-driven insights, and create visualizations similar to what front-office analysts use.
#
# Questions to Be Answered:
#
# How are plate discipline and power connected?
#
# Question: Do hitters with lower chase and whiff rates tend to have higher exit velocity or barrel rates?
#
# Value: Teams want players who combine contact skill and power — this shows which players actually achieve that balance.
#
# How do these relationships differ between left-handed and right-handed hitters?
#
# Value: Understanding handedness trends can inform scouting, lineup decisions, and player development strategy.
#
# Are these metrics improving or changing over time?
#
# Question: Has average exit velocity or whiff rate changed over the past five seasons?
#
# Value: Reveals league-wide evolution in hitting approaches — “launch angle era,” power focus, etc.
#
# What’s the correlation between advanced metrics and results (like wOBA)?
#
# Value: Helps identify which underlying skills (discipline or power) most predict offensive success.
#
# Visualization Ideas:
#
# Scatter Plot (Matplotlib/Seaborn):
#
# Variables: exit_velocity_avg (x) vs whiff_rate (y)
#
# Insight: Visualize the trade-off between contact and power; highlight players who excel at both.
#
# Box Plot:
#
# Variables: exit_velocity_avg grouped by handedness
#
# Insight: Compare left- vs right-handed hitter power profiles.
#
# Line Chart (Time Series):
#
# Variables: Average whiff_rate and exit_velocity_avg by year
#
# Insight: Track how player tendencies have changed over time.
#
# Correlation Heatmap:
#
# Variables: exit_velocity_avg, barrel_rate, whiff_rate, chase_rate, woba
#
# Insight: Show which variables most strongly relate to hitting success.
#
# Histogram or Density Plot:
#
# Variable: Distribution of barrel_rate across players
#
# Insight: Identify how rare elite contact quality really is.
#
# Interactive Scatter Plot (Plotly):
#
# Variables: exit_velocity_avg vs whiff_rate, hover showing player name and woba
#
# Insight: Let users explore player-level trends interactively.
#
# (Optional) Bar Chart:
#
# Variables: Top 10 players by barrel_rate or lowest whiff_rate
#
# Insight: Show standout performers in specific skill categories.

# %%
# 🚀 Importing some libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'
